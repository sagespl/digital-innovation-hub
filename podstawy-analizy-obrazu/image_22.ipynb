# %% [markdown]
# # Podstawy analizy obrazu

# %% [markdown]
# ## Obrazy
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tensory
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Uczenie maszynowe

# %% [markdown]
# ### Sieci neuronowe

# %% [markdown]
# - warstwy

# %% [markdown]
# - funkcje aktywacji

# %% [markdown]
# - optymalizatory

# %% [markdown]
# - funkcje straty

# %% [markdown]
# ## Zastosowania

# %% [markdown]
# - klasyfikacja obrazów

# %% [markdown]
# - rozpoznawanie obiektów

# %% [markdown]
# - segmentacja obrazów

# %% [markdown]
# - OCR

# %% [markdown]
# # Podstawy analizy obrazu
#
#
#
# <br><br>
#
# *Patryk Pilarski*
