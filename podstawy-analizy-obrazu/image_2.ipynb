# %% [markdown]
# # Uczenie maszynowe

# %% [markdown]
# - dział sztucznej inteligencji

# %% [markdown]
# - algorytmy poprawiające swoje działanie przez doświadczenie

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - uczenie nadzorowane - oznakowane dane

# %% [markdown]
# - uczenie nienadzorowane - nieoznakowane dane

# %% [markdown]
# ## Pojęcia

# %% [markdown]
# - zbiór danych

# %% [markdown]
# - rekord

# %% [markdown]
# - zmienne objaśniające

# %% [markdown]
# - zmienna celu

# %% [markdown]
# ## Uczenie z nadzorem

# %% [markdown]
# - regresja

# %% [markdown]
# - klasyfikacja

# %% [markdown]
# ## Klasyfikacja

# %% [markdown]
# - binarna

# %% [markdown]
# - wieloklasowa

# %% [markdown]
# ## Uczenie głębokie

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Trenowanie

# %% [markdown]
# - losowo inicjowane wagi

# %% [markdown]
# - iteracyjne modyfikowanie wag w celu dopasowania do danych

# %% [markdown]
# - wagi modyfikowane o określony wsółczynnik uczenia - learning rate

# %% [markdown]
# - dla predykcji ustalana jest wartość straty - loss

# %% [markdown]
# - z wykorzystaniem propagacji wstecznej modyfikowane są wagi
