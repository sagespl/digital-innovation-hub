# %% [markdown]
# # Segmentacja obrazów

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Zastosowania

# %% [markdown]
# - medycyna

# %% [markdown]
# - ekstrakcja obiektów

# %% [markdown]
# - rozpoznawanie czynności

# %% [markdown]
# - anotacja obrazów

# %% [markdown]
# ## Typy segmentacji

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Dane

# %% [markdown]
# **Narzędzia do anotacji**
#
# https://github.com/jsbroks/awesome-dataset-tools

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Penn-Fudan Database for Pedestrian Detection and Segmentation**
#
# https://www.cis.upenn.edu/~jshi/ped_html/

# %% [markdown]
# ```
# wget https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip
# unzip PennFudanPed.zip
# ```

# %%
from PIL import Image
import numpy as np

# %%
Image.open('PennFudanPed/PNGImages/FudanPed00074.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=421x370 at 0x7FF968B201C0>

# %%
mask = Image.open('PennFudanPed/PedMasks/FudanPed00074_mask.png')
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=421x370 at 0x7FF968B05940>

# %%
np.unique(np.array(mask))
# Out:
# array([0, 1, 2], dtype=uint8)

# %%
mask.putpalette([
    0, 0, 0,
    255, 0, 0, 
    255, 255, 0,
])
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=421x370 at 0x7FF968B05940>

# %%
Image.open('PennFudanPed/PNGImages/FudanPed00016.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=544x425 at 0x7FF968AA3130>

# %%
mask = Image.open('PennFudanPed/PedMasks/FudanPed00016_mask.png')
np.unique(np.array(mask))
# Out:
# array([0, 1, 2, 3], dtype=uint8)

# %%
mask.putpalette([
    0, 0, 0,
    255, 0, 0, 
    255, 255, 0,
    0, 255, 0,
])
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=544x425 at 0x7FF978DFDC10>

# %% [markdown]
# **PASCAL VOC**
#
# http://host.robots.ox.ac.uk/pascal/VOC/voc2012/

# %%
from torchvision import datasets

# %%
voc = datasets.VOCSegmentation(root='./data', download=True)
# Out:
# Using downloaded and verified file: ./data/VOCtrainval_11-May-2012.tar

# %%
voc[0]
# Out:
# (<PIL.Image.Image image mode=RGB size=500x281 at 0x7FF968B20130>,
#  <PIL.PngImagePlugin.PngImageFile image mode=P size=500x281 at 0x7FF978E096A0>)

# %%
img, mask = voc[0]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=500x281 at 0x7FF968B057C0>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=500x281 at 0x7FF948391AF0>

# %%
img, mask = voc[50]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7FF968D08910>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=500x375 at 0x7FF968EFCDC0>
